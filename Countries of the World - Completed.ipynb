# %% [markdown]
# # Countries of the World
# Country names linked to region, population, area size, GDP, mortality and more

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Import Dataset

# %%
world = pd.read_csv('countries_of_the_world.csv')

# %%
type(world)
# Out:
# pandas.core.frame.DataFrame

# %%
#Number of rows and columns in the dataset
world.shape
# Out:
# (227, 20)

# %%
#View the first five rows
world.head()
# Out:
#            country                               region  population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    area_sq_mi pop_density_per_sq_mi coastline_coastarea_ratio net_migration  \
# 0      647500                  48,0                      0,00         23,06
# 1       28748                 124,6                      1,26         -4,93
# 2     2381740                  13,8                      0,04         -0,39
# 3         199                 290,4                     58,29        -20,71
# 4         468                 152,1                      0,00           6,6
#
#   infant_mortality_per_1000_births  gdp_$_per_capita literacy phones_per_1000  \
# 0                           163,07             700.0     36,0             3,2
# 1                            21,52            4500.0     86,5            71,2
# 2                               31            6000.0     70,0            78,1
# 3                             9,27            8000.0     97,0           259,5
# 4                             4,05           19000.0    100,0           497,2
#
#   arable crops  other climate birthrate deathrate agriculture industry service
# 0  12,13  0,22  87,65       1      46,6     20,34        0,38     0,24    0,38
# 1  21,09  4,42  74,49       3     15,11      5,22       0,232    0,188   0,579
# 2   3,22  0,25  96,53       1     17,14      4,61       0,101      0,6   0,298
# 3     10    15     75       2     22,46      3,27         NaN      NaN     NaN
# 4   2,22     0  97,78       3      8,71      6,25         NaN      NaN     NaN

# %%
world['climate'].unique()
# Out:
# array(['1', '3', '2', nan, '4', '1,5', '2,5'], dtype=object)

# %%
world['climate'].nunique()
# Out:
# 6

# %%
#View the last 5 rows 
world.tail(8)
# Out:
#                 country                               region  population  \
# 219            Vietnam         ASIA (EX. NEAR EAST)             84402966
# 220     Virgin Islands               LATIN AMER. & CARIB          108605
# 221  Wallis and Futuna   OCEANIA                                   16025
# 222          West Bank   NEAR EAST                               2460492
# 223     Western Sahara   NORTHERN AFRICA                          273008
# 224              Yemen   NEAR EAST                              21456188
# 225             Zambia   SUB-SAHARAN AFRICA                     11502010
# 226           Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      area_sq_mi pop_density_per_sq_mi coastline_coastarea_ratio net_migration  \
# 219      329560                 256,1                      1,05         -0,45
# 220        1910                  56,9                      9,84         -8,94
# 221         274                  58,5                     47,08           NaN
# 222        5860                 419,9                      0,00          2,98
# 223      266000                   1,0                      0,42           NaN
# 224      527970                  40,6                      0,36             0
# 225      752614                  15,3                      0,00             0
# 226      390580                  31,3                      0,00             0
#
#     infant_mortality_per_1000_births  gdp_$_per_capita literacy  \
# 219                            25,95            2500.0     90,3
# 220                             8,03           17200.0      NaN
# 221                              NaN            3700.0     50,0
# 222                            19,62             800.0      NaN
# 223                              NaN               NaN      NaN
# 224                             61,5             800.0     50,2
# 225                            88,29             800.0     80,6
# 226                            67,69            1900.0     90,7
#
#     phones_per_1000 arable  crops  other climate birthrate deathrate  \
# 219           187,7  19,97   5,95  74,08       2     16,86      6,22
# 220           652,8  11,76   2,94   85,3       2     13,96      6,43
# 221           118,6      5     25     70       2       NaN       NaN
# 222           145,2   16,9  18,97  64,13       3     31,67      3,92
# 223             NaN   0,02      0  99,98       1       NaN       NaN
# 224            37,2   2,78   0,24  96,98       1     42,89       8,3
# 225             8,2   7,08   0,03   92,9       2        41     19,93
# 226            26,8   8,32   0,34  91,34       2     28,01     21,84
#
#     agriculture industry service
# 219       0,209     0,41   0,381
# 220        0,01     0,19     0,8
# 221         NaN      NaN     NaN
# 222        0,09     0,28    0,63
# 223         NaN      NaN     0,4
# 224       0,135    0,472   0,393
# 225        0,22     0,29   0,489
# 226       0,179    0,243   0,579

# %%
#Info about the column values if missing or not and their data types
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
# country                             227 non-null object
# region                              227 non-null object
# population                          227 non-null int64
# area_sq_mi                          227 non-null int64
# pop_density_per_sq_mi               227 non-null object
# coastline_coastarea_ratio           227 non-null object
# net_migration                       224 non-null object
# infant_mortality_per_1000_births    224 non-null object
# gdp_$_per_capita                    226 non-null float64
# literacy                            209 non-null object
# phones_per_1000                     223 non-null object
# arable                              225 non-null object
# crops                               225 non-null object
# other                               225 non-null object
# climate                             205 non-null object
# birthrate                           224 non-null object
# deathrate                           223 non-null object
# agriculture                         212 non-null object
# industry                            211 non-null object
# service                             212 non-null object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 20.4+ KB

# %%
#Summary Statistics of Int and Float Column Values in the Dataset
world.describe()
# Out:
#          population    area_sq_mi  gdp_$_per_capita
# count  2.270000e+02  2.270000e+02        226.000000
# mean   2.874028e+07  5.982270e+05       9689.823009
# std    1.178913e+08  1.790282e+06      10049.138513
# min    7.026000e+03  2.000000e+00        500.000000
# 25%    4.376240e+05  4.647500e+03       1900.000000
# 50%    4.786994e+06  8.660000e+04       5550.000000
# 75%    1.749777e+07  4.418110e+05      15700.000000
# max    1.313974e+09  1.707520e+07      55100.000000

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# * **Removing "," in the column values with "."**

# %% [markdown]
# * **Converting objects into float types**

# %%
str_columns = ['pop_density_per_sq_mi', 'coastline_coastarea_ratio', 'net_migration',
       'infant_mortality_per_1000_births', 'literacy',
       'phones_per_1000', 'arable', 'crops', 'other', 'climate',
       'birthrate', 'deathrate', 'agriculture', 'industry', 'service']
len(str_columns)
# Out:
# 15

# %%
for column in str_columns:
    world[column] = world[column].str.replace(',', '.')
    world[column] = pd.to_numeric(world[column])

# %%
world.head(1)
# Out:
#         country                         region  population  area_sq_mi  \
# 0  Afghanistan   ASIA (EX. NEAR EAST)             31056997      647500
#
#    pop_density_per_sq_mi  coastline_coastarea_ratio  net_migration  \
# 0                   48.0                        0.0          23.06
#
#    infant_mortality_per_1000_births  gdp_$_per_capita  literacy  \
# 0                            163.07             700.0      36.0
#
#    phones_per_1000  arable  crops  other  climate  birthrate  deathrate  \
# 0              3.2   12.13   0.22  87.65      1.0       46.6      20.34
#
#    agriculture  industry  service
# 0         0.38      0.24     0.38

# %%
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
# country                             227 non-null object
# region                              227 non-null object
# population                          227 non-null int64
# area_sq_mi                          227 non-null int64
# pop_density_per_sq_mi               227 non-null float64
# coastline_coastarea_ratio           227 non-null float64
# net_migration                       224 non-null float64
# infant_mortality_per_1000_births    224 non-null float64
# gdp_$_per_capita                    226 non-null float64
# literacy                            209 non-null float64
# phones_per_1000                     223 non-null float64
# arable                              225 non-null float64
# crops                               225 non-null float64
# other                               225 non-null float64
# climate                             205 non-null float64
# birthrate                           224 non-null float64
# deathrate                           223 non-null float64
# agriculture                         212 non-null float64
# industry                            211 non-null float64
# service                             212 non-null float64
# dtypes: float64(16), int64(2), object(2)
# memory usage: 33.7+ KB

# %% [markdown]
# * **Fill the missing values**

# %%
world.isnull().sum()
# Out:
# country                              0
# region                               0
# population                           0
# area_sq_mi                           0
# pop_density_per_sq_mi                0
# coastline_coastarea_ratio            0
# net_migration                        3
# infant_mortality_per_1000_births     3
# gdp_$_per_capita                     1
# literacy                            18
# phones_per_1000                      4
# arable                               2
# crops                                2
# other                                2
# climate                             22
# birthrate                            3
# deathrate                            4
# agriculture                         15
# industry                            16
# service                             15
# dtype: int64

# %%
#An example when to show mean and when to use a median
a = np.array([1, 4, np.nan, 2, 5])
np.nanmean(a)
print(np.nanmedian(a))

b = np.array([1, 4, np.nan, 2, 100])
np.nanmean(b)
print(np.nanmedian(b))
# Out:
# 3.0
# 3.0

# %%
plt.subplots(0,0,sharex='col')
world.hist(figsize=(15,15));

# %%
world.columns
# Out:
# Index(['country', 'region', 'population', 'area_sq_mi',
#        'pop_density_per_sq_mi', 'coastline_coastarea_ratio', 'net_migration',
#        'infant_mortality_per_1000_births', 'gdp_$_per_capita', 'literacy',
#        'phones_per_1000', 'arable', 'crops', 'other', 'climate', 'birthrate',
#        'deathrate', 'agriculture', 'industry', 'service'],
#       dtype='object')

# %%
fill_columns = ['net_migration',
       'infant_mortality_per_1000_births', 'gdp_$_per_capita', 'literacy',
     'phones_per_1000', 'arable', 'crops', 'other', 'climate',
       'birthrate', 'deathrate', 'agriculture', 'industry', 'service']
len(fill_columns)
# Out:
# 14

# %%
for column in fill_columns:    
    world[column] = world[column].fillna(world[column].median())

# %%
world.isnull().sum()
# Out:
# country                             0
# region                              0
# population                          0
# area_sq_mi                          0
# pop_density_per_sq_mi               0
# coastline_coastarea_ratio           0
# net_migration                       0
# infant_mortality_per_1000_births    0
# gdp_$_per_capita                    0
# literacy                            0
# phones_per_1000                     0
# arable                              0
# crops                               0
# other                               0
# climate                             0
# birthrate                           0
# deathrate                           0
# agriculture                         0
# industry                            0
# service                             0
# dtype: int64

# %%
world.head(10)
# Out:
#               country                               region  population  \
# 0        Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1            Albania   EASTERN EUROPE                          3581655
# 2            Algeria   NORTHERN AFRICA                        32930091
# 3     American Samoa   OCEANIA                                   57794
# 4            Andorra   WESTERN EUROPE                            71201
# 5             Angola   SUB-SAHARAN AFRICA                     12127071
# 6           Anguilla               LATIN AMER. & CARIB           13477
# 7  Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8          Argentina               LATIN AMER. & CARIB        39921833
# 9            Armenia                  C.W. OF IND. STATES      2976372
#
#    area_sq_mi  pop_density_per_sq_mi  coastline_coastarea_ratio  \
# 0      647500                   48.0                       0.00
# 1       28748                  124.6                       1.26
# 2     2381740                   13.8                       0.04
# 3         199                  290.4                      58.29
# 4         468                  152.1                       0.00
# 5     1246700                    9.7                       0.13
# 6         102                  132.1                      59.80
# 7         443                  156.0                      34.54
# 8     2766890                   14.4                       0.18
# 9       29800                   99.9                       0.00
#
#    net_migration  infant_mortality_per_1000_births  gdp_$_per_capita  \
# 0          23.06                            163.07             700.0
# 1          -4.93                             21.52            4500.0
# 2          -0.39                             31.00            6000.0
# 3         -20.71                              9.27            8000.0
# 4           6.60                              4.05           19000.0
# 5           0.00                            191.19            1900.0
# 6          10.76                             21.03            8600.0
# 7          -6.15                             19.46           11000.0
# 8           0.61                             15.18           11200.0
# 9          -6.47                             23.28            3500.0
#
#    literacy  phones_per_1000  arable  crops   other  climate  birthrate  \
# 0      36.0              3.2   12.13   0.22   87.65      1.0      46.60
# 1      86.5             71.2   21.09   4.42   74.49      3.0      15.11
# 2      70.0             78.1    3.22   0.25   96.53      1.0      17.14
# 3      97.0            259.5   10.00  15.00   75.00      2.0      22.46
# 4     100.0            497.2    2.22   0.00   97.78      3.0       8.71
# 5      42.0              7.8    2.41   0.24   97.35      2.0      45.11
# 6      95.0            460.0    0.00   0.00  100.00      2.0      14.17
# 7      89.0            549.9   18.18   4.55   77.27      2.0      16.93
# 8      97.1            220.4   12.31   0.48   87.21      3.0      16.73
# 9      98.6            195.7   17.55   2.30   80.15      4.0      12.07
#
#    deathrate  agriculture  industry  service
# 0      20.34        0.380     0.240    0.380
# 1       5.22        0.232     0.188    0.579
# 2       4.61        0.101     0.600    0.298
# 3       3.27        0.099     0.272    0.571
# 4       6.25        0.099     0.272    0.571
# 5      24.20        0.096     0.658    0.246
# 6       5.34        0.040     0.180    0.780
# 7       5.37        0.038     0.220    0.743
# 8       7.55        0.095     0.358    0.547
# 9       8.23        0.239     0.343    0.418

# %% [markdown]
# * **Duplicate values, if any**

# %%
world.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * **Dropping "other" column**

# %%
world.drop('other', axis=1, inplace=True)

# %%
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 19 columns):
# country                             227 non-null object
# region                              227 non-null object
# population                          227 non-null int64
# area_sq_mi                          227 non-null int64
# pop_density_per_sq_mi               227 non-null float64
# coastline_coastarea_ratio           227 non-null float64
# net_migration                       227 non-null float64
# infant_mortality_per_1000_births    227 non-null float64
# gdp_$_per_capita                    227 non-null float64
# literacy                            227 non-null float64
# phones_per_1000                     227 non-null float64
# arable                              227 non-null float64
# crops                               227 non-null float64
# climate                             227 non-null float64
# birthrate                           227 non-null float64
# deathrate                           227 non-null float64
# agriculture                         227 non-null float64
# industry                            227 non-null float64
# service                             227 non-null float64
# dtypes: float64(15), int64(2), object(2)
# memory usage: 32.0+ KB

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# * **Univariate Plotting - Boxplot**

# %%
world.boxplot(column='birthrate', figsize=(10,5));

# %% [markdown]
# * **Bivariate Plotting - Boxplot**

# %%
world.boxplot(column="arable",by="climate", figsize=(10,5))
plt.title("Arable land in each climate")
plt.suptitle("");

# %% [markdown]
# * **Bivariate Plotting - Barplot**

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='region',y='literacy',data=world, palette='Set3');
plt.xticks(rotation=90)
plt.grid()
plt.title('Literacy in different Regions')
plt.xlabel('Regions -->')
plt.ylabel('Literacy -->')
plt.show();

# %%
# <---- Line Plots ----->
#Grouping Data by region
grp = world.groupby('region')
x = grp['population'].agg(np.mean)
y = grp['gdp_$_per_capita'].agg(np.mean)
print(x)
print('------------------------------------------')
print(y)
# Out:
# region
# ASIA (EX. NEAR EAST)                   1.317137e+08
# BALTICS                                2.394991e+06
# C.W. OF IND. STATES                    2.334013e+07
# EASTERN EUROPE                         9.992893e+06
# LATIN AMER. & CARIB                    1.248499e+07
# NEAR EAST                              1.219177e+07
# NORTHERN AFRICA                        2.690119e+07
# NORTHERN AMERICA                       6.633446e+07
# OCEANIA                                1.577698e+06
# SUB-SAHARAN AFRICA                     1.469484e+07
# WESTERN EUROPE                         1.415500e+07
# Name: population, dtype: float64
# ------------------------------------------
# region
# ASIA (EX. NEAR EAST)                    8053.571429
# BALTICS                                11300.000000
# C.W. OF IND. STATES                     4000.000000
# EASTERN EUROPE                          9808.333333
# LATIN AMER. & CARIB                     8682.222222
# NEAR EAST                              10456.250000
# NORTHERN AFRICA                         5475.000000
# NORTHERN AMERICA                       26100.000000
# OCEANIA                                 8247.619048
# SUB-SAHARAN AFRICA                      2323.529412
# WESTERN EUROPE                         27046.428571
# Name: gdp_$_per_capita, dtype: float64

# %% [markdown]
# * **Multivariate Plotting - Heat Map (Correlation)**

# %%
# Why? - Model - Variance of features
world.corr()
# Out:
#                                   population  area_sq_mi  \
# population                          1.000000    0.469985
# area_sq_mi                          0.469985    1.000000
# pop_density_per_sq_mi              -0.028190   -0.066917
# coastline_coastarea_ratio          -0.068199   -0.095627
# net_migration                       0.000036    0.047472
# infant_mortality_per_1000_births    0.024298   -0.005594
# gdp_$_per_capita                   -0.038864    0.072491
# literacy                           -0.052456    0.025232
# phones_per_1000                    -0.029663    0.054703
# arable                              0.188704   -0.078881
# crops                              -0.059782   -0.142477
# climate                            -0.024411   -0.091789
# birthrate                          -0.044189   -0.065285
# deathrate                          -0.027215    0.041447
# agriculture                         0.006249   -0.044291
# industry                            0.100471    0.122299
# service                            -0.081254   -0.054677
#
#                                   pop_density_per_sq_mi  \
# population                                    -0.028190
# area_sq_mi                                    -0.066917
# pop_density_per_sq_mi                          1.000000
# coastline_coastarea_ratio                      0.241690
# net_migration                                  0.178011
# infant_mortality_per_1000_births              -0.142953
# gdp_$_per_capita                               0.196093
# literacy                                       0.101518
# phones_per_1000                                0.280802
# arable                                        -0.081404
# crops                                         -0.032330
# climate                                       -0.001699
# birthrate                                     -0.158282
# deathrate                                     -0.069021
# agriculture                                   -0.106589
# industry                                      -0.109147
# service                                        0.189446
#
#                                   coastline_coastarea_ratio  net_migration  \
# population                                        -0.068199       0.000036
# area_sq_mi                                        -0.095627       0.047472
# pop_density_per_sq_mi                              0.241690       0.178011
# coastline_coastarea_ratio                          1.000000      -0.134051
# net_migration                                     -0.134051       1.000000
# infant_mortality_per_1000_births                  -0.137171      -0.024945
# gdp_$_per_capita                                   0.049614       0.381877
# literacy                                           0.127766      -0.005668
# phones_per_1000                                    0.152497       0.239220
# arable                                            -0.121735      -0.060119
# crops                                              0.339312      -0.344059
# climate                                           -0.033284      -0.020845
# birthrate                                         -0.075378      -0.066087
# deathrate                                         -0.161813       0.033964
# agriculture                                       -0.043559      -0.108935
# industry                                          -0.189342      -0.025006
# service                                            0.183868       0.114301
#
#                                   infant_mortality_per_1000_births  \
# population                                                0.024298
# area_sq_mi                                               -0.005594
# pop_density_per_sq_mi                                    -0.142953
# coastline_coastarea_ratio                                -0.137171
# net_migration                                            -0.024945
# infant_mortality_per_1000_births                          1.000000
# gdp_$_per_capita                                         -0.596424
# literacy                                                 -0.756088
# phones_per_1000                                          -0.666106
# arable                                                   -0.110154
# crops                                                    -0.066185
# climate                                                  -0.333355
# birthrate                                                 0.845636
# deathrate                                                 0.656874
# agriculture                                               0.707926
# industry                                                  0.009511
# service                                                  -0.619634
#
#                                   gdp_$_per_capita  literacy  phones_per_1000  \
# population                               -0.038864 -0.052456        -0.029663
# area_sq_mi                                0.072491  0.025232         0.054703
# pop_density_per_sq_mi                     0.196093  0.101518         0.280802
# coastline_coastarea_ratio                 0.049614  0.127766         0.152497
# net_migration                             0.381877 -0.005668         0.239220
# infant_mortality_per_1000_births         -0.596424 -0.756088        -0.666106
# gdp_$_per_capita                          1.000000  0.495909         0.830903
# literacy                                  0.495909  1.000000         0.565414
# phones_per_1000                           0.830903  0.565414         1.000000
# arable                                    0.021194  0.085631         0.059448
# crops                                    -0.217685  0.044724        -0.150963
# climate                                   0.295621  0.359711         0.345543
# birthrate                                -0.645865 -0.754837        -0.719766
# deathrate                                -0.198155 -0.394168        -0.257397
# agriculture                              -0.572473 -0.597133        -0.581195
# industry                                 -0.029482  0.040135        -0.143477
# service                                   0.532418  0.481603         0.626184
#
#                                     arable     crops   climate  birthrate  \
# population                        0.188704 -0.059782 -0.024411  -0.044189
# area_sq_mi                       -0.078881 -0.142477 -0.091789  -0.065285
# pop_density_per_sq_mi            -0.081404 -0.032330 -0.001699  -0.158282
# coastline_coastarea_ratio        -0.121735  0.339312 -0.033284  -0.075378
# net_migration                    -0.060119 -0.344059 -0.020845  -0.066087
# infant_mortality_per_1000_births -0.110154 -0.066185 -0.333355   0.845636
# gdp_$_per_capita                  0.021194 -0.217685  0.295621  -0.645865
# literacy                          0.085631  0.044724  0.359711  -0.754837
# phones_per_1000                   0.059448 -0.150963  0.345543  -0.719766
# arable                            1.000000  0.095226  0.346590  -0.183561
# crops                             0.095226  1.000000  0.007573   0.114433
# climate                           0.346590  0.007573  1.000000  -0.413845
# birthrate                        -0.183561  0.114433 -0.413845   1.000000
# deathrate                         0.053051 -0.204403  0.009837   0.396017
# agriculture                      -0.021570  0.053917 -0.190383   0.669846
# industry                         -0.057425 -0.110649 -0.089623  -0.053082
# service                           0.085316  0.048249  0.259324  -0.542931
#
#                                   deathrate  agriculture  industry   service
# population                        -0.027215     0.006249  0.100471 -0.081254
# area_sq_mi                         0.041447    -0.044291  0.122299 -0.054677
# pop_density_per_sq_mi             -0.069021    -0.106589 -0.109147  0.189446
# coastline_coastarea_ratio         -0.161813    -0.043559 -0.189342  0.183868
# net_migration                      0.033964    -0.108935 -0.025006  0.114301
# infant_mortality_per_1000_births   0.656874     0.707926  0.009511 -0.619634
# gdp_$_per_capita                  -0.198155    -0.572473 -0.029482  0.532418
# literacy                          -0.394168    -0.597133  0.040135  0.481603
# phones_per_1000                   -0.257397    -0.581195 -0.143477  0.626184
# arable                             0.053051    -0.021570 -0.057425  0.085316
# crops                             -0.204403     0.053917 -0.110649  0.048249
# climate                            0.009837    -0.190383 -0.089623  0.259324
# birthrate                          0.396017     0.669846 -0.053082 -0.542931
# deathrate                          1.000000     0.387979  0.031261 -0.352791
# agriculture                        0.387979     1.000000 -0.319742 -0.612064
# industry                           0.031261    -0.319742  1.000000 -0.542978
# service                           -0.352791    -0.612064 -0.542978  1.000000

# %%
#Visual representation in form of heatmap for correlated data
plt.figure(figsize=(15,10))
ax=plt.axes()
sns.heatmap(data=world.iloc[:,2:].corr(),annot=True,fmt='.2f',cmap='coolwarm',ax=ax)
ax.set_title('Heatmap showing correlated values for the Dataset')
plt.show()

# %% [markdown]
# **corr > 0**
# 1. literacy
# 2. phone_per_1000
# 3. service
#
# **corr < 0**
# 1. infant_mortality_per_1000_births
# 2. birthrate
# 3. agriculture
